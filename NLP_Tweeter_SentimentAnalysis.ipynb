# %%
import tweepy
import matplotlib.pyplot as plt
from  textblob import TextBlob 
import time

# %%
# all 4 authentication keys to access twitter API
# to connect as OAth handler or jump serever / revers proxy server
consumer_key = "8AO6OU5ubyi4XO47b1C7Sjdlz"
consumer_sec = "FS1usPrfPolvjLXbwGka5N8TWkOZhUsdxGmmTwuO016koesUSt"

# from proxy server we need to connect
access_token = "1151573806680592384-OUFeUtpsRFZM6jQxl1AG99NEjlY0Kt"
access_token_sec = "KKHmkHkDGVaDof8XK4fKKI52DmNl4vZlaXnx85WRfd4Lr"

# %%
# connected to jump server of twitter
auth=tweepy.OAuthHandler(consumer_key,consumer_sec)

# %%
# now we can connect from jump server to web server of twitter
auth.set_access_token(access_token,access_token_sec)

# %%
# now we can connect to API storge server of twitter
api_connect=tweepy.API(auth)

# %%
# now you can search any topic on twitter
tweet_data=api_connect.search('Modi',count=100)

# %%
pos=0
neg=0
neu=0

# printing line by line
for tweet in tweet_data:
   #print(tweet.text)
   analysis=TextBlob(tweet.text) # here it will apply NLP\
   print(analysis.sentiment)
   # now checking polarity only
   if analysis.sentiment.polarity > 0:
      print("posative")
      pos=pos+1
   elif analysis.sentiment.polarity == 0 :
      print("Neutral")
      neu=neu+1
   else :
      print("Negative")
      neg=neg+1
      
# ploting graphs
plt.xlabel("tags")
plt.ylabel("polarity")
#plt.bar(['pos','neg','neu'],[pos,neg,neu])
plt.pie([pos,neg,neu],labels=['pos','neg','neu'],autopct="%1.1f%%")
plt.show()
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.625)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.625)
# Neutral
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# posative
# Sentiment(polarity=0.0, subjectivity=0.14285714285714285)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.2380952380952381, subjectivity=0.6428571428571429)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.6)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.25, subjectivity=0.375)
# posative
# Sentiment(polarity=-0.3666666666666667, subjectivity=0.6277777777777778)
# Negative
# Sentiment(polarity=-0.1, subjectivity=0.1)
# Negative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=-0.125, subjectivity=0.375)
# Negative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.25)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.16, subjectivity=0.5399999999999999)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.16, subjectivity=0.5399999999999999)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=-0.1, subjectivity=0.1)
# Negative
# Sentiment(polarity=-0.05, subjectivity=0.0)
# Negative
# Sentiment(polarity=0.36818181818181817, subjectivity=0.6772727272727272)
# posative
# Sentiment(polarity=0.3666666666666667, subjectivity=0.7000000000000001)
# posative
# Sentiment(polarity=0.8, subjectivity=0.7)
# posative
# Sentiment(polarity=0.55, subjectivity=0.7)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# Neutral
# Sentiment(polarity=0.5, subjectivity=0.5)
# posative
# Sentiment(polarity=0.175, subjectivity=0.4833333333333334)
# posative
# Sentiment(polarity=0.5375, subjectivity=0.55)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.26666666666666666, subjectivity=0.5333333333333333)
# posative
# Sentiment(polarity=0.46875, subjectivity=0.75)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.5, subjectivity=0.8)
# posative
# Sentiment(polarity=-0.041666666666666664, subjectivity=0.225)
# Negative
# Sentiment(polarity=0.0, subjectivity=0.25)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.2380952380952381, subjectivity=0.6428571428571429)
# posative
# Sentiment(polarity=0.1375, subjectivity=0.6375)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.7534722222222222)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.16, subjectivity=0.5399999999999999)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.2380952380952381, subjectivity=0.6428571428571429)
# posative
# Sentiment(polarity=-0.4375, subjectivity=1.0)
# Negative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# posative
# Sentiment(polarity=0.1, subjectivity=0.3)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.5, subjectivity=0.5)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=-0.18333333333333335, subjectivity=0.35)
# Negative
# Sentiment(polarity=-0.3333333333333333, subjectivity=0.6666666666666666)
# Negative
# Sentiment(polarity=0.55, subjectivity=0.7)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=1.0, subjectivity=0.7)
# posative
# Sentiment(polarity=0.25, subjectivity=0.3333333333333333)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.16, subjectivity=0.5399999999999999)
# posative
# Sentiment(polarity=0.5, subjectivity=0.6944444444444444)
# posative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
